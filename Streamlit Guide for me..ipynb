# %% [markdown]
# # Guide for me

# %%
import streamlit as st
import pandas as pd
import numpy as np

# %%
st.title('Uber pickups in NYC')
# Out:
# 2022-06-08 11:04:58.659
# ...
#   command:
#
#     streamlit run C:\Users\anoop\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
streamlit run C:\Users\anoop\anaconda3\lib\site-packages\ipykernel_launcher.py
# Out:
#   File "<ipython-input-3-3b135cb24e86>", line 1
#     streamlit run C:\Users\anoop\anaconda3\lib\site-packages\ipykernel_launcher.py
#               ^
# SyntaxError: invalid syntax

# %%
# to run the streamlit package it has to be run in the folder where its installed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1st change directory to :
#     C:\Users\anoop\SEM 2\z_Streamlit

# %% [markdown]
# streamlit run [app.py]    # it has to have a .py extension

# %% [markdown]
# you will get output as this :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It will look like this

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you edit the py file you don't need to restart the prompt again

# %% [markdown]
# only refresh the old window on the chrome tab

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# to deploy the app

# %% [markdown]
# create an empty requirements.txt at the location of the app.py file

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Upload the txt and app.py to github repo

# %% [markdown]
# Sign in to streamlit

# %% [markdown]
# https://share.streamlit.io/

# %% [markdown]
# point the repo app.py file

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### SUMMARY

# %% [markdown]
# ![image.png](attachment:image.png)
